# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent

agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Filipe and my favourite color is black")

response = agent.invoke(
    {"messages": [question]}
)

# %%
for message in response["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# Hello my name is Filipe and my favourite color is black
# ================================== Ai Message ==================================
#
# Hi Filipe! Nice to meet you. Black is a versatile color—great for style, design, and contrast. What would you like to do today? I can help with ideas for outfits or room decor, color palettes that pair well with black, or anything else you’re curious about. Tell me your interests and we’ll dive in.

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]}
)

for message in response["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What's my favourite colour?
# ================================== Ai Message ==================================
#
# I don’t know your favourite colour yet. Want me to guess, or should we do a quick 3-question quiz to figure it out?
#
# If you’d like a guess: blue is a very common favorite. Is that right, or should I run the quick quiz?

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Filipe and my favourite colour is black")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config
)

# %%
for message in response["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# Hello my name is Filipe and my favourite colour is black
# ================================== Ai Message ==================================
#
# Nice to meet you, Filipe. Black is a powerful, versatile color.
#
# What would you like to do today? We could chat about fashion, design, color palettes, or anything else you’re interested in. If you’d like, I can suggest color pairings that work well with black. Some quick ideas:
# - Black + white: classic and clean
# - Black + gray: minimalist and sophisticated
# - Black + gold/brass: luxurious
# - Black + red: bold and energetic
# - Black + emerald/royal blue: rich and elegant
# - Black + soft pink: modern contrast
#
# Tell me a bit about your project or what you’re in the mood for, and I’ll tailor the suggestions.

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config
)

for message in response["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# Hello my name is Filipe and my favourite colour is black
# ================================== Ai Message ==================================
#
# Nice to meet you, Filipe. Black is a powerful, versatile color.
#
# What would you like to do today? We could chat about fashion, design, color palettes, or anything else you’re interested in. If you’d like, I can suggest color pairings that work well with black. Some quick ideas:
# - Black + white: classic and clean
# - Black + gray: minimalist and sophisticated
# - Black + gold/brass: luxurious
# - Black + red: bold and energetic
# - Black + emerald/royal blue: rich and elegant
# - Black + soft pink: modern contrast
#
# Tell me a bit about your project or what you’re in the mood for, and I’ll tailor the suggestions.
# ================================ Human Message =================================
#
# What's my favourite colour?
# ================================== Ai Message ==================================
#
# Your favourite colour is black. Want some color pairings or ideas for using black in a project?
