# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from dataclasses import dataclass
from langchain.agents.middleware import dynamic_prompt, ModelRequest

@dataclass
class LanguageContext:
    user_language: str = "English"

@dynamic_prompt
def user_language_prompt(request: ModelRequest) -> str:
    """Generate system prompt based on user role."""
    user_language = request.runtime.context.user_language
    base_prompt = "You are a helpful assistant."

    if user_language != "English":
        return f"{base_prompt} only respond in {user_language}"
    elif user_language == "English":
        return base_prompt

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    context_schema=LanguageContext,
    middleware=[user_language_prompt]
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"message": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="Irish")
)

print(response["messages"][-1].content)
# Out:
# Dia dhuit! Cad is féidir liom a dhéanamh duit inniu? Inis dom do cheist nó an tasc, agus déanfaimid é.

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"message": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="Spanish")
)

print(response["messages"][-1].content)
# Out:
# ¡Hola! ¿En qué puedo ayudarte hoy? Puedo:
#
# - Explicar conceptos o dudas
# - Traducir textos
# - Redactar o corregir textos
# - Ayudarte con código o algoritmos
# - Planificar proyectos o estudiar
# - Resolver problemas de matemáticas o lógica
#
# Dime qué necesitas y el nivel de detalle que prefieres.

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"message": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="French")
)

print(response["messages"][-1].content)
# Out:
# Bonjour ! Comment puis-je vous aider aujourd’hui ? Voici quelques possibilités:
#
# - Rédiger, corriger ou relire un texte
# - Traduire entre le français et une autre langue
# - Expliquer un concept ou répondre à une question
# - Résumer un article ou un document
# - Aider à programmer (explications, débogage, exemples)
# - Préparer une lettre, un CV, une motivation
# - Donner des conseils pratiques (organisation, productivité, apprentissage)
#
# Dites-moi ce dont vous avez besoin et je m’occupe de tout.
