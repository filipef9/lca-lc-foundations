# %% [markdown]
# ## Local MCP server

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient({
    "local_server": {
        "transport": "stdio",
        "command": "python",
        "args": ["resources/2.1_mcp_server.py"],
    }
})

# %%
# get tools
tools = await client.get_tools()

# get resources
resources = await client.get_resources("local_server")

# get prompts
prompt = await client.get_prompt("local_server", "prompt")
prompt = prompt[0].content

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
    system_prompt=prompt
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Tell me about the langchain-mcp-adapters library.")]},
    config=config
)

# %%
for message in response["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# Tell me about the langchain-mcp-adapters library.
# ================================== Ai Message ==================================
# Tool Calls:
#   search_web (call_u87bS0dZXNBC4Dr7KXm0lVhD)
#  Call ID: call_u87bS0dZXNBC4Dr7KXm0lVhD
#   Args:
#     query: langchain-mcp-adapters library
# ================================= Tool Message =================================
# Name: search_web
#
# [{'type': 'text', 'text': '{\n  "query": "langchain-mcp-adapters library",\n  "follow_up_questions": null,\n  "answer": null,\n  "images": [],\n  "results": [\n    {\n      "url": "https://github.com/langchain-ai/langchainjs-mcp-adapters",\n      "title": "langchain-ai/langchainjs-mcp-adapters: ** THIS REPO ... - GitHub",\n      "content": "# Search code, repositories, users, issues, pull requests... You signed in with another tab or window. You signed out in another tab or window. You switched accounts on another tab or window. langchain-ai   /  **langchainjs-mcp-adapters**  Public archive. \\\\*\\\\* THIS REPO HAS MOVED TO  \\\\*\\\\* Adapters for integrating Model Context Protocol (MCP) tools with LangChain.js applications, supporting both stdio and SSE transports. 246 stars   34 forks   Branches   Tags   Activity. # langchain-ai/langchainjs-mcp-adapters. | RELEASE\\\\_NOTES.md | RELEASE\\\\_NOTES.md |  |  |. | tsconfig.cjs.json | tsconfig.cjs.json |  |  |. | tsconfig.examples.json | tsconfig.examples.json |  |  |. | tsconfig.tests.json | tsconfig.tests.json |  |  |. ## Repository files navigation. # LangChain.js MCP Adapters. This library provides a lightweight wrapper to allow Model Context Protocol (MCP) services to be used with LangChain.js. \\\\*\\\\* THIS REPO HAS MOVED TO  \\\\*\\\\* Adapters for integrating Model Context Protocol (MCP) tools with LangChain.js applications, supporting both stdio and SSE transports. javascript   typescript   mcp   ai-tools   langchain   llm-tools   openai-functions   langchainjs   llm-agents   agent-tools   llm-integration   model-context-protocol.",\n      "score": 0.8868231,\n      "raw_content": null\n    },\n    {\n      "url": "https://changelog.langchain.com/announcements/mcp-adapters-for-langchain-and-langgraph",\n      "title": "MCP Adapters for LangChain and LangGraph",\n      "content": "# LangChain Changelog. Sign up for our newsletter to stay up to date. # MCP Adapters for LangChain and LangGraph. The **LangChain MCP Adapters** is a package that makes it easy to use **Anthropic Model Context Protocol (MCP) tools** with LangChain & LangGraph. * Converts **MCP tools** into **LangChain- & LangGraph-compatible tools**. * Enables interaction with tools across multiple **MCP servers**. * Seamlessly integrates the **hundreds of tool servers** already published into LangGraph Agents. ### Why use MCP Adapters:. This adapter makes it simple to connect LangChain and LangGraph with the growing ecosystem of MCP tool servers. Instead of manually adapting each tool, you can now integrate them seamlessly. It also allows agents to pull from multiple MCP servers at once, making it easier to combine different tools for more powerful applications. MCP is gaining serious traction, and this adapter helps LangGraph agents take full advantage. ##### Subscribe to updates.",\n      "score": 0.8729662,\n      "raw_content": null\n    },\n    {\n      "url": "https://reference.langchain.com/python/langchain_mcp_adapters/",\n      "title": "langchain-mcp-adapters",\n      "content": "# `langchain-mcp-adapters`¶. Client for connecting to multiple MCP servers and loading LC tools/resources. This module provides the `MultiServerMCPClient` class for managing connections to multiple MCP servers and loading tools, prompts, and resources from them. Loads LangChain-compatible tools, prompts and resources from MCP servers. | \\\\_\\\\_init\\\\_\\\\_ (`langchain_mcp_adapters.client.MultiServerMCPClient.__init__`)\\">\\\\_\\\\_init\\\\_\\\\_ | Initialize a `MultiServerMCPClient` with MCP servers connections. | session  `async`  (`langchain_mcp_adapters.client.MultiServerMCPClient.session`)\\">session | Connect to an MCP server and initialize a session. | get\\\\_tools  `async`  (`langchain_mcp_adapters.client.MultiServerMCPClient.get_tools`)\\">get\\\\_tools | Get a list of all tools from all connected servers. | get\\\\_resources  `async`  (`langchain_mcp_adapters.client.MultiServerMCPClient.get_resources`)\\"> ...
# ================================== Ai Message ==================================
#
# Here’s a concise overview of the LangChain MCP Adapters library and what it’s for.
#
# What it is
# - A bridge between Anthropic Model Context Protocol (MCP) tool servers and LangChain/LangGraph.
# - It converts MCP tools into LangChain-compatible tools and lets LangChain agents interact with tools across multiple MCP servers.
# - Available for both Python and JavaScript (LangChain.js), with separate repositories and docs for each language.
#
# Key features
# - MultiServerMCPClient
#   - Connect to multiple MCP servers at once.
#   - Load tools, prompts, and resources from all connected MCP servers.
#   - Retrieve the list of tools and resources across servers.
# - Loading tools and resources
#   - load_mcp_tools: load MCP tools so they can be used as LangChain tools by agents.
#   - load_mcp_resources: load resources (prompts, etc.) from MCP servers.
# - Sessions and tooling
#   - session management for interacting with MCP servers.
#   - get_tools and get_resources for discovery and introspection.
# - Interception and callbacks
#   - ToolCallInterceptor and Callbacks support interception or customization around tool invocations.
# - Transports
#   - Supports local/remote MCP servers via transports such as stdio (local subprocess) and HTTP/SSE (remote servers).
#   - This enables both local tool servers and remote MCP servers to be used with LangChain/LangGraph.
# - Language bindings
#   - Python: langchain_mcp_adapters package (MultiServerMCPClient, load_mcp_tools, etc.).
#   - JavaScript: @langchain/mcp-adapters (LangChain.js) with a similar MultiServerMCPClient interface.
# - Ecosystem fit
#   - Enables LangChain and LangGraph agents to leverage the hundreds of MCP tool servers that are already published.
#   - Useful for combining tools from different MCP servers to create richer agent capabilities.
#
# Why you’d use it
# - You already have MCP tool servers and want to use them with LangChain/LangGraph agents without writing per-tool adapters.
# - You need to pull tools from multiple MCP servers and use them in a single agent workflow.
# - You want to reuse existing MCP tools (and their contexts) in LangChain-powered apps.
#
# Where to learn more
# - Python package: PyPI page for langchain-mcp-adapters (docs and usage examples).
# - Python docs/reference (high-level): LangChain reference page for langchain_mcp_adapters (MultiServerMCPClient, load_mcp_tools, etc.).
# - JavaScript/LangChain.js variant: langchainjs-mcp-adapters repo (GitHub) and the LangChain JavaScript MCP docs.
# - LangChain changelog article: “MCP Adapters for LangChain and LangGraph” (overview and rationale).
# - Additional context: The MCP docs page from LangChain describes MCP and how LangChain agents can use MCP tools via the adapters, with example client initialization and tool loading.
#
# Notes and current status
# - Some MCP adapters repos note that the JS adapter has moved or been updated; check the “THIS REPO HAS MOVED TO” note in the GitHub repo you’re looking at to ensure you’re using the current/maintained source.
# - The Python and JavaScript ecosystems mirror each other in approach (MultiServerMCPClient, tool loading, and resource loading), but the exact API calls differ by language.
#
# Would you like a quickstart for a specific language?
# - I can give you a minimal Python example using MultiServerMCPClient to connect to two MCP servers and load MCP tools, or a JavaScript example showing how to initialize the client and load tools for a LangChain.js agent. If you tell me your MCP server setup (HTTP URL vs. local stdio, and whether you want to load tools only or also resources), I’ll tailor a small, runnable snippet.

# %% [markdown]
# ## Online MCP

# %%
client = MultiServerMCPClient({
    "time": {
        "transport": "stdio",
        "command": "uvx",
        "args": [
            "mcp-server-time",
            "--local-timezone=America/Sao_Paulo"
        ]
    }
})

tools = await client.get_tools()

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=tools
)

# %%
question = HumanMessage(content="What time is it?")

response = await agent.ainvoke(
    {"messages": [question]}
)

for message in response["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What time is it?
# ================================== Ai Message ==================================
# Tool Calls:
#   get_current_time (call_fTyFab1hLb5rhHSIo9qdNa4P)
#  Call ID: call_fTyFab1hLb5rhHSIo9qdNa4P
#   Args:
#     timezone: America/Sao_Paulo
# ================================= Tool Message =================================
# Name: get_current_time
#
# [{'type': 'text', 'text': '{\n  "timezone": "America/Sao_Paulo",\n  "datetime": "2026-01-02T18:41:04-03:00",\n  "day_of_week": "Friday",\n  "is_dst": false\n}', 'id': 'lc_e8b91e57-83d0-4def-a1b9-ae203def9b85'}]
# ================================== Ai Message ==================================
#
# It’s 18:41 (6:41 PM) on Friday, January 2, 2026 in São Paulo (UTC−3). Want me to convert this to another timezone?
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
